# %% [markdown]
# <a href="https://colab.research.google.com/github/asad1729/OpenGoogleCOLLAB/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("/content/240852098_248745653657331_4458397732297354066_n.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (427, 640, 3)

# %%
plt.imshow(image)

# %%
new_image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
plt.imshow(new_image)

# %%
"""
1. Splitting Image Channels 
"""
r,g,b=cv2.split(new_image)
'''print ('r', r.shape)
print ('g', g.shape)
print ('b', b.shape)'''
new_image = cv2.merge((r,g,b))

# %%
"""
2. Resize of Image 
"""
s = 10
w = int(new_image.shape[1]*s/100)
h = int(new_image.shape[0]*s/100)
dim = (w,h)
re_size = cv2.resize(new_image, dim, interpolation = cv2.INTER_AREA)
re_size.shape
plt.imshow(re_size)

# %%
"""
3. Rotate Image 
"""
(h,w) = new_image.shape[:2]
c = (w/2 , h/2)

angle = 90
m = cv2.getRotationMatrix2D(c,angle, 1.0)
rotate_90 = cv2.warpAffine(new_image, m, (h,w))

# %%
plt.imshow(rotate_90)
